# %% [markdown]
# # Kinematics

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
g = -9.8;
y0 = 1.6;
v0 = 3;
t = np.arange(0,1,0.05);
y = y0 + v0*t + 1/2*g*t**2;

plt.plot(t,y)
plt.xlabel('time in sec')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
